# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")
df.head(5)
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
# df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# len(df)
df['Unnamed: 32']  #NaN is also a data type
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 564   NaN
# 565   NaN
# 566   NaN
# 567   NaN
# 568   NaN
# Name: Unnamed: 32, Length: 569, dtype: float64

# %%
df=df.drop(columns=["id","Unnamed: 32"])
df.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
#same output with diffrent syntax to count the no of values in column
df.diagnosis
df["diagnosis"].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df["diagnosis"]=df["diagnosis"].map({"M":1, "B":0})
df["diagnosis"].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df.describe().T
# Out:
#                          count        mean  ...          75%         max
# diagnosis                569.0    0.372583  ...     1.000000     1.00000
# radius_mean              569.0   14.127292  ...    15.780000    28.11000
# texture_mean             569.0   19.289649  ...    21.800000    39.28000
# perimeter_mean           569.0   91.969033  ...   104.100000   188.50000
# area_mean                569.0  654.889104  ...   782.700000  2501.00000
# smoothness_mean          569.0    0.096360  ...     0.105300     0.16340
# compactness_mean         569.0    0.104341  ...     0.130400     0.34540
# concavity_mean           569.0    0.088799  ...     0.130700     0.42680
# concave points_mean      569.0    0.048919  ...     0.074000     0.20120
# symmetry_mean            569.0    0.181162  ...     0.195700     0.30400
# fractal_dimension_mean   569.0    0.062798  ...     0.066120     0.09744
# radius_se                569.0    0.405172  ...     0.478900     2.87300
# ...

# %%
for col in df.columns:
    plt.figure(figsize= (6, 8))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
plt.figure(figsize= (6, 4))
sns.boxplot(x='diagnosis', y='area_worst',data=df)
plt.show()

# %%
plt.figure(figsize= (6, 4))
sns.boxplot(x='diagnosis', y='concavity_worst',data=df)
plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(data=df,x=col,hue='diagnosis',kde=True,element="step")
    plt.title(col)
    plt.show()

# %%
plt.figure(figsize = (6,4))
sns.histplot(df['area_se'],kde=True)
plt.title("area_se - original")
plt.show()

# %% [markdown]
# create a list of skewed column

# %%
skewed_cols=df.skew()[df.skew()>2].index
skewed_cols
# Out:
# Index(['radius_se', 'perimeter_se', 'area_se', 'smoothness_se', 'concavity_se',
#        'symmetry_se', 'fractal_dimension_se'],
#       dtype='object')

# %%
df[skewed_cols].apply(lambda x: np.log1p(x))
# Out:
#      radius_se  perimeter_se  ...  symmetry_se  fractal_dimension_se
# 0     0.739554      2.260617  ...     0.029588              0.006174
# 1     0.434053      1.481150  ...     0.013794              0.003526
# 2     0.557098      1.720084  ...     0.022251              0.004561
# 3     0.402527      1.491780  ...     0.057920              0.009166
# 4     0.563722      1.862218  ...     0.017408              0.005102
# ..         ...           ...  ...          ...                   ...
# 564   0.777488      2.160215  ...     0.011078              0.004230
# 565   0.568434      1.825033  ...     0.018802              0.002495
# 566   0.375968      1.487270  ...     0.013094              0.003884
# 567   0.545807      1.912796  ...     0.022974              0.006166
# 568   0.326205      1.266384  ...     0.026408              0.002779
#
# [569 rows x 7 columns]

# %%
df[skewed_cols].skew()
# Out:
# radius_se               3.088612
# perimeter_se            3.443615
# area_se                 5.447186
# smoothness_se           2.314450
# concavity_se            5.110463
# symmetry_se             2.195133
# fractal_dimension_se    3.923969
# dtype: float64

# %%
plt.figure(figsize = (6,3))
sns.histplot(df['concavity_se'],kde=True)
plt.title("concavity_se - after log")
plt.show()

# %%
plt.figure(figsize = (6,3))
sns.boxplot(x="diagnosis", y="concavity_se", data=df)
plt.show()

# %%
X= df.drop("diagnosis",axis=1)
y= df["diagnosis"]

# %%
X.head()
# Out:
#    radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0        17.99         10.38  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# X_train=training data, y_trian= training lable

# %%
X_train.shape
# Out:
# (381, 30)

# %%
y_train.shape
# Out:
# (381,)

# %%
y_test.shape
# Out:
# (188,)

# %%
X_test.shape
# Out:
# (188, 30)

# %% [markdown]
# EDA= preprossing= feature_engineering= divide data x,y = train test= standered scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((381, 30), (188, 30))

# %% [markdown]
# .fit()--> calculate mean and std from training only
# transform()--> applies learned parameters
#
# Test data never influences training statistics

# %% [markdown]
# low variance threshold

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
selector=VarianceThreshold(0.01)
X_train_var = selector.fit_transform(X_train_scaled)
X_test_var = selector.transform(X_test_scaled)
X_train_var.shape, X_train_scaled.shape
# Out:
# ((381, 30), (381, 30))

# %% [markdown]
# Correlation based feature removal
# this data is famous for multicolinearity

# %%
corr_matrix=pd.DataFrame(X_train_scaled, columns=X.columns).corr().abs()

# %%
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape),k=1).astype(bool))
to_drop = [col for col in upper.columns if any(upper[col]>0.9)]
to_drop
# Out:
# ['perimeter_mean',
#  'area_mean',
#  'concave points_mean',
#  'perimeter_se',
#  'area_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'concave points_worst']

# %%
X_train_corr = pd.DataFrame(X_train_scaled, columns=X.columns).drop(columns= to_drop)
X_test_corr = pd.DataFrame(X_test_scaled, columns=X.columns).drop(columns= to_drop)
X_train_corr
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0       0.355820     -1.726647  ...        0.518443                 0.989255
# 1      -0.373267      0.508813  ...       -0.632367                -0.114696
# 2       1.403358     -0.151449  ...        1.025874                -0.033698
# 3      -0.479417     -0.448568  ...        0.232321                -0.392242
# 4      -0.482211      0.159817  ...       -0.320953                -0.333900
# ..           ...           ...  ...             ...                      ...
# 376    -1.480026     -1.078175  ...       -1.002270                 1.408405
# 377    -0.711272     -0.208043  ...       -0.129678                 0.421136
# 378     0.028988     -0.564113  ...       -0.679791                -1.265094
# 379    -0.057609      0.096149  ...        0.459954                 1.244143
# 380    -0.560427      0.308376  ...       -0.306726                -0.835748
#
# [381 rows x 20 columns]

# %% [markdown]
# Tree based Feature importance

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf= RandomForestClassifier(random_state=42)

# %%
rf.fit(X_train_corr, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
importances = pd.Series(rf.feature_importances_, index = X_test_corr.columns)
importances.sort_values(ascending = False).head(10)
# Out:
# radius_mean               0.201433
# concavity_worst           0.171161
# concavity_mean            0.149707
# radius_se                 0.079186
# compactness_worst         0.071433
# compactness_mean          0.052646
# texture_mean              0.038835
# concavity_se              0.031332
# symmetry_worst            0.028652
# fractal_dimension_mean    0.022280
# dtype: float64

# %%
plt.figure(figsize=(8,6))
importances.plot(kind = "barh")
plt.gca().invert_yaxis()
plt.title("Feature importance (All 20 features)")
plt.xlabel("importance")
plt.show()

# %% [markdown]
# # PCA (Principal Components Analysis)

# %% [markdown]
# only after Correlation and is used for doing the dimensionality reduction.

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA()
pca.fit(X_train_corr)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.show()

# %%
pca = PCA(n_components=0.95)
X_train_pca = pca.fit_transform(X_train_corr)
X_test_pca = pca.transform(X_test_corr)

X_train_pca.shape
# Out:
# (381, 11)

# %% [markdown]
# LDA for classification
# PCA for regression
